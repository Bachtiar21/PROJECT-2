# %% [markdown]
# # 1. DATA TRAIN

# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('employee_attrition_train.csv')
df_train
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     50.0        No      Travel_Rarely     1126.0  Research & Development
# 1     36.0        No      Travel_Rarely      216.0  Research & Development
# 2     21.0       Yes      Travel_Rarely      337.0                   Sales
# 3     50.0        No  Travel_Frequently     1246.0         Human Resources
# 4     52.0        No      Travel_Rarely      994.0  Research & Development
# ...    ...       ...                ...        ...                     ...
# 1024   NaN        No      Travel_Rarely      750.0  Research & Development
# 1025  41.0        No      Travel_Rarely      447.0  Research & Development
# 1026  22.0       Yes  Travel_Frequently     1256.0  Research & Development
# 1027  29.0        No      Travel_Rarely     1378.0  Research & Development
# 1028  50.0        No      Travel_Rarely      264.0                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       893 non-null    float64
#  1   Attrition                 1029 non-null   object
#  2   BusinessTravel            1024 non-null   object
#  3   DailyRate                 1002 non-null   float64
#  4   Department                1029 non-null   object
#  5   DistanceFromHome          934 non-null    float64
#  6   Education                 1029 non-null   int64
#  7   EducationField            1029 non-null   object
#  8   EmployeeCount             1029 non-null   int64
#  9   EmployeeNumber            1029 non-null   int64
#  10  EnvironmentSatisfaction   1029 non-null   int64
#  11  Gender                    1029 non-null   object
#  12  HourlyRate                1029 non-null   int64
# ...

# %% [markdown]
# ## 1.1 Data Cleaning
#
# Mengisi missing values dengan mean

# %%
#Cek Apakah Ada Data yang Kosong?
df_train.isnull().values.any()
# Out:
# True

# %%
#Data kosong pada kolom
#Data yang kosong akan diolah untuk diisi dengan mean-nya
df_train.isnull().sum()
# Out:
# Age                         136
# Attrition                     0
# BusinessTravel                5
# DailyRate                    27
# Department                    0
# DistanceFromHome             95
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 5
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# ...

# %%
df_train_clean = df_train

# %%
df_train_clean
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     50.0        No      Travel_Rarely     1126.0  Research & Development
# 1     36.0        No      Travel_Rarely      216.0  Research & Development
# 2     21.0       Yes      Travel_Rarely      337.0                   Sales
# 3     50.0        No  Travel_Frequently     1246.0         Human Resources
# 4     52.0        No      Travel_Rarely      994.0  Research & Development
# ...    ...       ...                ...        ...                     ...
# 1024   NaN        No      Travel_Rarely      750.0  Research & Development
# 1025  41.0        No      Travel_Rarely      447.0  Research & Development
# 1026  22.0       Yes  Travel_Frequently     1256.0  Research & Development
# 1027  29.0        No      Travel_Rarely     1378.0  Research & Development
# 1028  50.0        No      Travel_Rarely      264.0                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### 1.1.1 Age

# %%
#Mengambil kolom Age untuk diisi dengan mean-nya
Age = df_train_clean['Age']
Age
# Out:
# 0       50.0
# 1       36.0
# 2       21.0
# 3       50.0
# 4       52.0
#         ...
# 1024     NaN
# 1025    41.0
# 1026    22.0
# 1027    29.0
# 1028    50.0
# Name: Age, Length: 1029, dtype: float64

# %%
len(Age[pd.isnull(Age)])
#total data kosong pada Age
# Out:
# 136

# %%
Age.count()
#total data terisi pada Age
# Out:
# 893

# %%
Age.describe()
#lihat mean
# Out:
# count    893.000000
# mean      37.930571
# std        9.395978
# min       18.000000
# 25%       31.000000
# 50%       37.000000
# 75%       44.000000
# max       60.000000
# Name: Age, dtype: float64

# %%
df_train_clean.Age = df_train.Age.fillna(value=df_train.Age.mean())
df_train_clean
#penggunaan mean hanya untuk data numeric
#data 1024 pada age yang sebelumnya NaN, sekarang telah terisi 37.930571
# Out:
#             Age Attrition     BusinessTravel  DailyRate  \
# 0     50.000000        No      Travel_Rarely     1126.0
# 1     36.000000        No      Travel_Rarely      216.0
# 2     21.000000       Yes      Travel_Rarely      337.0
# 3     50.000000        No  Travel_Frequently     1246.0
# 4     52.000000        No      Travel_Rarely      994.0
# ...         ...       ...                ...        ...
# 1024  37.930571        No      Travel_Rarely      750.0
# 1025  41.000000        No      Travel_Rarely      447.0
# 1026  22.000000       Yes  Travel_Frequently     1256.0
# 1027  29.000000        No      Travel_Rarely     1378.0
# 1028  50.000000        No      Travel_Rarely      264.0
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0     Research & Development               1.0          2        Medical
# 1     Research & Development               6.0          2        Medical
# ...

# %%
Age.count()
#data Age yang terisi atau tidak null
# Out:
# 1029

# %%
len(Age[pd.isnull(Age)])
# Out:
# 0

# %% [markdown]
# ### 1.1.2 Mean DailyRate

# %%
DailyRate = df_train_clean['DailyRate']
DailyRate
# Out:
# 0       1126.0
# 1        216.0
# 2        337.0
# 3       1246.0
# 4        994.0
#          ...
# 1024     750.0
# 1025     447.0
# 1026    1256.0
# 1027    1378.0
# 1028     264.0
# Name: DailyRate, Length: 1029, dtype: float64

# %%
len(DailyRate[pd.isnull(DailyRate)])
# Out:
# 27

# %%
DailyRate.count()
# Out:
# 1002

# %%
DailyRate.describe()
# Out:
# count    1002.000000
# mean      800.528942
# std       408.109828
# min       102.000000
# 25%       458.250000
# 50%       801.500000
# 75%      1162.000000
# max      1496.000000
# Name: DailyRate, dtype: float64

# %%
df_train_clean.DailyRate = df_train_clean.DailyRate.fillna(value=df_train_clean.DailyRate.mean())
df_train_clean
# Out:
#             Age Attrition     BusinessTravel  DailyRate  \
# 0     50.000000        No      Travel_Rarely     1126.0
# 1     36.000000        No      Travel_Rarely      216.0
# 2     21.000000       Yes      Travel_Rarely      337.0
# 3     50.000000        No  Travel_Frequently     1246.0
# 4     52.000000        No      Travel_Rarely      994.0
# ...         ...       ...                ...        ...
# 1024  37.930571        No      Travel_Rarely      750.0
# 1025  41.000000        No      Travel_Rarely      447.0
# 1026  22.000000       Yes  Travel_Frequently     1256.0
# 1027  29.000000        No      Travel_Rarely     1378.0
# 1028  50.000000        No      Travel_Rarely      264.0
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0     Research & Development               1.0          2        Medical
# 1     Research & Development               6.0          2        Medical
# ...

# %%
DailyRate.count()
#data DailyRate yang terisi atau tidak null
# Out:
# 1029

# %%
len(DailyRate[pd.isnull(DailyRate)])
#data DailyRate yang null
# Out:
# 0

# %% [markdown]
# ### 1.1.3 Mean DistanceFromHome

# %%
DistanceFromHome = df_train['DistanceFromHome']
DistanceFromHome
# Out:
# 0        1.0
# 1        6.0
# 2        7.0
# 3        NaN
# 4        7.0
#         ...
# 1024    28.0
# 1025     NaN
# 1026     NaN
# 1027    13.0
# 1028     9.0
# Name: DistanceFromHome, Length: 1029, dtype: float64

# %%
len(DistanceFromHome[pd.isnull(DistanceFromHome)])
# Out:
# 95

# %%
DistanceFromHome.count()
# Out:
# 934

# %%
DistanceFromHome.describe()
# Out:
# count    934.000000
# mean       9.930407
# std        8.421791
# min        1.000000
# 25%        2.000000
# 50%        8.000000
# 75%       16.000000
# max       29.000000
# Name: DistanceFromHome, dtype: float64

# %%
df_train_clean.DistanceFromHome = df_train_clean.DistanceFromHome.fillna(value=df_train_clean.DistanceFromHome.mean())
df_train_clean
# Out:
#             Age Attrition     BusinessTravel  DailyRate  \
# 0     50.000000        No      Travel_Rarely     1126.0
# 1     36.000000        No      Travel_Rarely      216.0
# 2     21.000000       Yes      Travel_Rarely      337.0
# 3     50.000000        No  Travel_Frequently     1246.0
# 4     52.000000        No      Travel_Rarely      994.0
# ...         ...       ...                ...        ...
# 1024  37.930571        No      Travel_Rarely      750.0
# 1025  41.000000        No      Travel_Rarely      447.0
# 1026  22.000000       Yes  Travel_Frequently     1256.0
# 1027  29.000000        No      Travel_Rarely     1378.0
# 1028  50.000000        No      Travel_Rarely      264.0
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0     Research & Development          1.000000          2        Medical
# 1     Research & Development          6.000000          2        Medical
# ...

# %%
DistanceFromHome.count()
#data DistanceFromHome yang terisi atau tidak null
# Out:
# 1029

# %%
len(DistanceFromHome[pd.isnull(DistanceFromHome)])
#data DistanceFromHome yang null
# Out:
# 0

# %% [markdown]
# ###  1.1.4 Mean BusinessTravel

# %%
# Untuk menormalisasi harus berupa data numeric
# Encoder BusinessTravel Variable
# converting type of columns to 'category'
df_train_clean['BusinessTravel'] = df_train_clean['BusinessTravel'].astype('category')
# Assigning numerical values and storing in another column
df_train_clean['BusinessTravel'] = df_train_clean['BusinessTravel'].cat.codes
df_train_clean
# Out:
#             Age Attrition  BusinessTravel  DailyRate              Department  \
# 0     50.000000        No               2     1126.0  Research & Development
# 1     36.000000        No               2      216.0  Research & Development
# 2     21.000000       Yes               2      337.0                   Sales
# 3     50.000000        No               1     1246.0         Human Resources
# 4     52.000000        No               2      994.0  Research & Development
# ...         ...       ...             ...        ...                     ...
# 1024  37.930571        No               2      750.0  Research & Development
# 1025  41.000000        No               2      447.0  Research & Development
# 1026  22.000000       Yes               1     1256.0  Research & Development
# 1027  29.000000        No               2     1378.0  Research & Development
# 1028  50.000000        No               2      264.0                   Sales
#
# ...

# %%
BusinessTravel = df_train_clean['BusinessTravel']
BusinessTravel
# Out:
# 0       2
# 1       2
# 2       2
# 3       1
# 4       2
#        ..
# 1024    2
# 1025    2
# 1026    1
# 1027    2
# 1028    2
# Name: BusinessTravel, Length: 1029, dtype: int8

# %%
len(BusinessTravel[pd.isnull(BusinessTravel)])
# Out:
# 0

# %%
BusinessTravel.count()
# Out:
# 1029

# %% [markdown]
# ###  1.1.5 MaritalStatus Mean

# %%
# Encoder BusinessTravel Variable
# converting type of columns to 'category'
df_train_clean['MaritalStatus'] = df_train_clean['MaritalStatus'].astype('category')
# Assigning numerical values and storing in another column
df_train_clean['MaritalStatus'] = df_train_clean['MaritalStatus'].cat.codes
df_train_clean
# Out:
#             Age Attrition  BusinessTravel  DailyRate              Department  \
# 0     50.000000        No               2     1126.0  Research & Development
# 1     36.000000        No               2      216.0  Research & Development
# 2     21.000000       Yes               2      337.0                   Sales
# 3     50.000000        No               1     1246.0         Human Resources
# 4     52.000000        No               2      994.0  Research & Development
# ...         ...       ...             ...        ...                     ...
# 1024  37.930571        No               2      750.0  Research & Development
# 1025  41.000000        No               2      447.0  Research & Development
# 1026  22.000000       Yes               1     1256.0  Research & Development
# 1027  29.000000        No               2     1378.0  Research & Development
# 1028  50.000000        No               2      264.0                   Sales
#
# ...

# %%
MaritalStatus = df_train_clean['MaritalStatus']
MaritalStatus
# Out:
# 0       0
# 1       0
# 2       2
# 3       1
# 4       2
#        ..
# 1024    1
# 1025    2
# 1026    1
# 1027    1
# 1028    1
# Name: MaritalStatus, Length: 1029, dtype: int8

# %%
len(MaritalStatus[pd.isnull(MaritalStatus)])
# Out:
# 0

# %%
MaritalStatus.count()
# Out:
# 1029

# %% [markdown]
# ### 1.1.6 EmployeeCount

# %%
# EmployeeCount = df_train_clean['EmployeeCount']
# EmployeeCount
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1024    1
# 1025    1
# 1026    1
# 1027    1
# 1028    1
# Name: EmployeeCount, Length: 1029, dtype: int64

# %%
# len(EmployeeCount[pd.isnull(EmployeeCount)])
# Out:
# 0

# %%
# EmployeeCount.count()
# Out:
# 1029

# %%
# EmployeeCount.describe()
# Out:
# count    1029.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: EmployeeCount, dtype: float64

# %%
# df_train_clean.EmployeeCount = df_train_clean.EmployeeCount.fillna(value=df_train_clean.EmployeeCount.mean())
# df_train_clean
# Out:
#             Age Attrition  BusinessTravel  DailyRate              Department  \
# 0     50.000000        No               2     1126.0  Research & Development
# 1     36.000000        No               2      216.0  Research & Development
# 2     21.000000       Yes               2      337.0                   Sales
# 3     50.000000        No               1     1246.0         Human Resources
# 4     52.000000        No               2      994.0  Research & Development
# ...         ...       ...             ...        ...                     ...
# 1024  37.930571        No               2      750.0  Research & Development
# 1025  41.000000        No               2      447.0  Research & Development
# 1026  22.000000       Yes               1     1256.0  Research & Development
# 1027  29.000000        No               2     1378.0  Research & Development
# 1028  50.000000        No               2      264.0                   Sales
#
# ...

# %% [markdown]
# ### 1.1.7 StandardHours

# %%
# StandardHours = df_train_clean['StandardHours']
# StandardHours
# Out:
# 0       80
# 1       80
# 2       80
# 3       80
# 4       80
#         ..
# 1024    80
# 1025    80
# 1026    80
# 1027    80
# 1028    80
# Name: StandardHours, Length: 1029, dtype: int64

# %%
# len(StandardHours[pd.isnull(StandardHours)])
# Out:
# 0

# %%
# StandardHours.count()
# Out:
# 1029

# %%
# StandardHours.describe()
# Out:
# count    1029.0
# mean       80.0
# std         0.0
# min        80.0
# 25%        80.0
# 50%        80.0
# 75%        80.0
# max        80.0
# Name: StandardHours, dtype: float64

# %%
# df_train_clean.StandardHours = df_train_clean.StandardHours.fillna(value=df_train_clean.StandardHours.mean())
# df_train_clean
# Out:
#             Age Attrition  BusinessTravel  DailyRate              Department  \
# 0     50.000000        No               2     1126.0  Research & Development
# 1     36.000000        No               2      216.0  Research & Development
# 2     21.000000       Yes               2      337.0                   Sales
# 3     50.000000        No               1     1246.0         Human Resources
# 4     52.000000        No               2      994.0  Research & Development
# ...         ...       ...             ...        ...                     ...
# 1024  37.930571        No               2      750.0  Research & Development
# 1025  41.000000        No               2      447.0  Research & Development
# 1026  22.000000       Yes               1     1256.0  Research & Development
# 1027  29.000000        No               2     1378.0  Research & Development
# 1028  50.000000        No               2      264.0                   Sales
#
# ...

# %% [markdown]
# ##  1.2 Cek Data Cleaning

# %%
df_train_clean
# Out:
#             Age Attrition  BusinessTravel  DailyRate              Department  \
# 0     50.000000        No               2     1126.0  Research & Development
# 1     36.000000        No               2      216.0  Research & Development
# 2     21.000000       Yes               2      337.0                   Sales
# 3     50.000000        No               1     1246.0         Human Resources
# 4     52.000000        No               2      994.0  Research & Development
# ...         ...       ...             ...        ...                     ...
# 1024  37.930571        No               2      750.0  Research & Development
# 1025  41.000000        No               2      447.0  Research & Development
# 1026  22.000000       Yes               1     1256.0  Research & Development
# 1027  29.000000        No               2     1378.0  Research & Development
# 1028  50.000000        No               2      264.0                   Sales
#
# ...

# %%
len(df_train_clean[pd.isnull(df_train_clean).any(axis=1)])
# Out:
# 0

# %%
#Cek Apakah Ada Data yang Kosong?
df_train_clean.isnull().values.any()
# Out:
# False

# %%
#Data kosong pada kolom
df_train_clean.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df_train_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1029 non-null   float64
#  1   Attrition                 1029 non-null   object
#  2   BusinessTravel            1029 non-null   int8
#  3   DailyRate                 1029 non-null   float64
#  4   Department                1029 non-null   object
#  5   DistanceFromHome          1029 non-null   float64
#  6   Education                 1029 non-null   int64
#  7   EducationField            1029 non-null   object
#  8   EmployeeCount             1029 non-null   int64
#  9   EmployeeNumber            1029 non-null   int64
#  10  EnvironmentSatisfaction   1029 non-null   int64
#  11  Gender                    1029 non-null   object
#  12  HourlyRate                1029 non-null   int64
# ...

# %% [markdown]
# ## 1.3 Visualisasi Korelasi Antar Variable Data Train

# %%
import matplotlib.pyplot as plt # plotting
import seaborn as sns
sns.set()

# %%
df_train_clean.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Plot korelasi dengan heatmap
plt.figure(figsize=(28,20)) 
plt.title(f'Correlation Matrix for Data Training ', fontsize=30)
sns.heatmap(df_train_clean[['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']].corr(), annot=True, cmap='magma_r')
# Out:
# <AxesSubplot:title={'center':'Correlation Matrix for Data Training '}>

# %%
df_train_clean.corr().abs()
# Out:
#                                Age  BusinessTravel  DailyRate  \
# Age                       1.000000        0.067385   0.021999
# BusinessTravel            0.067385        1.000000   0.010968
# DailyRate                 0.021999        0.010968   1.000000
# DistanceFromHome          0.032016        0.042224   0.017619
# Education                 0.212995        0.020100   0.055751
# EmployeeCount                  NaN             NaN        NaN
# EmployeeNumber            0.013967        0.006448   0.053794
# EnvironmentSatisfaction   0.022540        0.010913   0.001417
# HourlyRate                0.018563        0.036792   0.028113
# JobInvolvement            0.022422        0.032331   0.046314
# JobLevel                  0.487301        0.020665   0.021170
# JobSatisfaction           0.007144        0.011966   0.021878
# MaritalStatus             0.085950        0.062328   0.084055
# MonthlyIncome             0.477357        0.038137   0.022844
# ...

# %%
df_train_clean2 = df_train_clean.drop(['Attrition','BusinessTravel','DailyRate', 'Department','DistanceFromHome','Education',
                                       'EducationField', 'EmployeeCount', 'EmployeeNumber','EnvironmentSatisfaction', 'Gender', 
                                       'HourlyRate','JobInvolvement', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
                                       'MonthlyRate','NumCompaniesWorked','Over18', 'OverTime', 'RelationshipSatisfaction',
                                       'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance'], axis=1)
# mengambil data berdasar pedoman interpretasi koefisien korelasi
# Data Sedang = 0,40 - 0,599
# Data Kuat = 0,60 - 0,799
# Data Sangat Kuat = 0,80 - 1,0

# %%
df_train_clean2
# Out:
#             Age  JobLevel  MonthlyIncome  PercentSalaryHike  \
# 0     50.000000         4          17399                 22
# 1     36.000000         2           4941                 20
# 2     21.000000         1           2679                 13
# 3     50.000000         5          18200                 11
# 4     52.000000         3          10445                 19
# ...         ...       ...            ...                ...
# 1024  37.930571         2           3407                 17
# 1025  41.000000         2           6870                 12
# 1026  22.000000         1           2853                 11
# 1027  29.000000         2           4025                 13
# 1028  50.000000         5          19331                 16
#
#       PerformanceRating  TotalWorkingYears  YearsAtCompany  \
# 0                     4                 32               5
# 1                     4                  7               3
# 2                     3                  1               1
# ...

# %%
df_train_clean2.corr().abs()
# Out:
#                               Age  JobLevel  MonthlyIncome  PercentSalaryHike  \
# Age                      1.000000  0.487301       0.477357           0.010788
# JobLevel                 0.487301  1.000000       0.952756           0.018906
# MonthlyIncome            0.477357  0.952756       1.000000           0.020387
# PercentSalaryHike        0.010788  0.018906       0.020387           1.000000
# PerformanceRating        0.006980  0.007530       0.010082           0.774110
# TotalWorkingYears        0.647349  0.786130       0.773499           0.003086
# YearsAtCompany           0.282861  0.544920       0.525311           0.014896
# YearsInCurrentRole       0.206222  0.418767       0.396541           0.010240
# YearsSinceLastPromotion  0.171819  0.350313       0.346647           0.003155
# YearsWithCurrManager     0.177369  0.365449       0.336437           0.000334
#
#                          PerformanceRating  TotalWorkingYears  YearsAtCompany  \
# ...

# %%
plt.figure(figsize=(10,8))
plt.title(f'Correlation Matrix for Data Train', fontsize=25)
sns.heatmap(df_train_clean2.corr(), annot=True, cmap='magma_r')
#mengambil data berdasar pedoman interpretasi koefisien korelasi
# Data Sedang = 0,40 - 0,599
# Data Kuat = 0,60 - 0,799
# Data Sangat Kuat = 0,80 - 1,0
# Out:
# <AxesSubplot:title={'center':'Correlation Matrix for Data Train'}>

# %% [markdown]
# # 2. DATA TEST

# %%
df_test = pd.read_csv('employee_attrition_test.csv')
df_test
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0     NaN      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# ..    ...                ...        ...                     ...
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438   NaN      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440   NaN      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                 NaN          3          Medical              1
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       386 non-null    float64
#  1   BusinessTravel            436 non-null    object
#  2   DailyRate                 427 non-null    float64
#  3   Department                441 non-null    object
#  4   DistanceFromHome          387 non-null    float64
#  5   Education                 441 non-null    int64
#  6   EducationField            441 non-null    object
#  7   EmployeeCount             441 non-null    int64
#  8   EmployeeNumber            441 non-null    int64
#  9   EnvironmentSatisfaction   441 non-null    int64
#  10  Gender                    441 non-null    object
#  11  HourlyRate                441 non-null    int64
#  12  JobInvolvement            441 non-null    int64
# ...

# %% [markdown]
# ## 2.1 Data Cleaning

# %%
#Cek Apakah Ada Data yang Kosong?
df_test.isnull().values.any()
# Out:
# True

# %%
#Data kosong pada kolom
#Data yang kosong akan diolah untuk diisi dengan mean-nya
df_test.isnull().sum()
# Out:
# Age                         55
# BusinessTravel               5
# DailyRate                   14
# Department                   0
# DistanceFromHome            54
# Education                    0
# EducationField               0
# EmployeeCount                0
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                       0
# HourlyRate                   0
# JobInvolvement               0
# JobLevel                     0
# JobRole                      0
# JobSatisfaction              0
# MaritalStatus                3
# MonthlyIncome                0
# MonthlyRate                  0
# NumCompaniesWorked           0
# Over18                       0
# OverTime                     0
# PercentSalaryHike            0
# PerformanceRating            0
# RelationshipSatisfaction     0
# StandardHours                0
# StockOptionLevel             0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# ...

# %%
df_test_clean = df_test
df_test_clean
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0     NaN      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# ..    ...                ...        ...                     ...
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438   NaN      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440   NaN      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                 NaN          3          Medical              1
# ...

# %% [markdown]
# ### 2.1.1 Age

# %%
#Mengambil kolom Age untuk diisi dengan mean-nya
Age = df_test_clean['Age']
Age
# Out:
# 0       NaN
# 1      53.0
# 2      24.0
# 3      45.0
# 4      36.0
#        ...
# 436    33.0
# 437    27.0
# 438     NaN
# 439    39.0
# 440     NaN
# Name: Age, Length: 441, dtype: float64

# %%
len(Age[pd.isnull(Age)])
# Out:
# 55

# %%
Age.count()
# Out:
# 386

# %%
Age.describe()
# Out:
# count    386.000000
# mean      38.000000
# std        8.832055
# min       18.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max       60.000000
# Name: Age, dtype: float64

# %%
df_test_clean.Age = df_test_clean.Age.fillna(value=df_test_clean.Age.mean())
df_test_clean
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0    38.0      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# ..    ...                ...        ...                     ...
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438  38.0      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440  38.0      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                 NaN          3          Medical              1
# ...

# %%
Age.count()
#data DailyRate yang terisi atau tidak null
# Out:
# 441

# %%
len(Age[pd.isnull(Age)])
#data DistanceFromHome yang null
# Out:
# 0

# %% [markdown]
# ### 2.1.2 DailyRate

# %%
#Mengambil kolom DailyRate untuk diisi dengan mean-nya
DailyRate = df_test_clean['DailyRate']
DailyRate
# Out:
# 0       866.0
# 1      1084.0
# 2       240.0
# 3      1339.0
# 4      1396.0
#         ...
# 436     430.0
# 437     210.0
# 438    1157.0
# 439    1383.0
# 440     104.0
# Name: DailyRate, Length: 441, dtype: float64

# %%
len(DailyRate[pd.isnull(DailyRate)])
# Out:
# 14

# %%
DailyRate.count()
# Out:
# 427

# %%
DailyRate.describe()
# Out:
# count     427.000000
# mean      800.960187
# std       395.674732
# min       104.000000
# 25%       466.000000
# 50%       796.000000
# 75%      1142.500000
# max      1499.000000
# Name: DailyRate, dtype: float64

# %%
df_test_clean.DailyRate = df_test_clean.DailyRate.fillna(value=df_test_clean.DailyRate.mean())
df_test_clean
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0    38.0      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# ..    ...                ...        ...                     ...
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438  38.0      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440  38.0      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0                 NaN          3          Medical              1
# ...

# %%
DailyRate.count()
#data DailyRate yang terisi atau tidak null
# Out:
# 441

# %%
len(DailyRate[pd.isnull(DailyRate)])
#data DistanceFromHome yang null
# Out:
# 0

# %% [markdown]
# ### 2.1.3 DistanceFromHome

# %%
#Mengambil kolom DistanceFromHome untuk diisi dengan mean-nya
DistanceFromHome = df_test_clean['DistanceFromHome']
DistanceFromHome
# Out:
# 0       NaN
# 1      13.0
# 2      22.0
# 3       7.0
# 4       NaN
#        ...
# 436     7.0
# 437     1.0
# 438     2.0
# 439     2.0
# 440     2.0
# Name: DistanceFromHome, Length: 441, dtype: float64

# %%
len(DistanceFromHome[pd.isnull(DistanceFromHome)])
# Out:
# 54

# %%
DistanceFromHome.count()
# Out:
# 387

# %%
DistanceFromHome.describe()
# Out:
# count    387.000000
# mean       9.459948
# std        8.123102
# min        1.000000
# 25%        2.000000
# 50%        8.000000
# 75%       15.000000
# max       29.000000
# Name: DistanceFromHome, dtype: float64

# %%
df_test_clean.DistanceFromHome = df_test_clean.DistanceFromHome.fillna(value=df_test_clean.DistanceFromHome.mean())
df_test_clean
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0    38.0      Travel_Rarely      866.0                   Sales
# 1    53.0      Travel_Rarely     1084.0  Research & Development
# 2    24.0      Travel_Rarely      240.0         Human Resources
# 3    45.0      Travel_Rarely     1339.0  Research & Development
# 4    36.0      Travel_Rarely     1396.0  Research & Development
# ..    ...                ...        ...                     ...
# 436  33.0  Travel_Frequently      430.0                   Sales
# 437  27.0         Non-Travel      210.0                   Sales
# 438  38.0      Travel_Rarely     1157.0  Research & Development
# 439  39.0      Travel_Rarely     1383.0         Human Resources
# 440  38.0      Travel_Rarely      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0            9.459948          3          Medical              1
# ...

# %%
DistanceFromHome.count()
#data DailyRate yang terisi atau tidak null
# Out:
# 441

# %%
len(DistanceFromHome[pd.isnull(DistanceFromHome)])
#data DistanceFromHome yang null
# Out:
# 0

# %% [markdown]
# ### 2.1.4 Bussines Travel

# %%
# Untuk menormalisasi harus berupa data numeric
# Encoder BusinessTravel Variable
# converting type of columns to 'category'
df_test_clean['BusinessTravel'] = df_test_clean['BusinessTravel'].astype('category')
# Assigning numerical values and storing in another column
df_test_clean['BusinessTravel'] = df_test_clean['BusinessTravel'].cat.codes
df_test_clean
# Out:
#       Age  BusinessTravel  DailyRate              Department  \
# 0    38.0               2      866.0                   Sales
# 1    53.0               2     1084.0  Research & Development
# 2    24.0               2      240.0         Human Resources
# 3    45.0               2     1339.0  Research & Development
# 4    36.0               2     1396.0  Research & Development
# ..    ...             ...        ...                     ...
# 436  33.0               1      430.0                   Sales
# 437  27.0               0      210.0                   Sales
# 438  38.0               2     1157.0  Research & Development
# 439  39.0               2     1383.0         Human Resources
# 440  38.0               2      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0            9.459948          3          Medical              1
# 1           13.000000          2          Medical              1
# ...

# %%
BusinessTravel = df_test_clean['BusinessTravel']
BusinessTravel
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 436    1
# 437    0
# 438    2
# 439    2
# 440    2
# Name: BusinessTravel, Length: 441, dtype: int8

# %%
len(BusinessTravel[pd.isnull(BusinessTravel)])
# Out:
# 0

# %%
BusinessTravel.count()
# Out:
# 441

# %% [markdown]
# ### 2.1.5 Marital Status

# %%
# Untuk menormalisasi harus berupa data numeric
# Encoder MaritalStatus Variable
# converting type of columns to 'category'
df_test_clean['MaritalStatus'] = df_test_clean['MaritalStatus'].astype('category')
# Assigning numerical values and storing in another column
df_test_clean['MaritalStatus'] = df_test_clean['MaritalStatus'].cat.codes
df_test_clean
# Out:
#       Age  BusinessTravel  DailyRate              Department  \
# 0    38.0               2      866.0                   Sales
# 1    53.0               2     1084.0  Research & Development
# 2    24.0               2      240.0         Human Resources
# 3    45.0               2     1339.0  Research & Development
# 4    36.0               2     1396.0  Research & Development
# ..    ...             ...        ...                     ...
# 436  33.0               1      430.0                   Sales
# 437  27.0               0      210.0                   Sales
# 438  38.0               2     1157.0  Research & Development
# 439  39.0               2     1383.0         Human Resources
# 440  38.0               2      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0            9.459948          3          Medical              1
# 1           13.000000          2          Medical              1
# ...

# %%
MaritalStatus = df_test_clean['MaritalStatus']
MaritalStatus
# Out:
# 0      2
# 1      0
# 2      1
# 3      0
# 4      2
#       ..
# 436    1
# 437    1
# 438    1
# 439    1
# 440    0
# Name: MaritalStatus, Length: 441, dtype: int8

# %%
len(MaritalStatus[pd.isnull(MaritalStatus)])
# Out:
# 0

# %%
MaritalStatus.count()
# Out:
# 441

# %% [markdown]
# ## 2.2 Cek Data Cleaning

# %%
df_test_clean
# Out:
#       Age  BusinessTravel  DailyRate              Department  \
# 0    38.0               2      866.0                   Sales
# 1    53.0               2     1084.0  Research & Development
# 2    24.0               2      240.0         Human Resources
# 3    45.0               2     1339.0  Research & Development
# 4    36.0               2     1396.0  Research & Development
# ..    ...             ...        ...                     ...
# 436  33.0               1      430.0                   Sales
# 437  27.0               0      210.0                   Sales
# 438  38.0               2     1157.0  Research & Development
# 439  39.0               2     1383.0         Human Resources
# 440  38.0               2      104.0  Research & Development
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 0            9.459948          3          Medical              1
# 1           13.000000          2          Medical              1
# ...

# %%
len(df_test_clean[pd.isnull(df_test_clean).any(axis=1)])
# Out:
# 0

# %%
#Cek Apakah Ada Data yang Kosong?
df_test_clean.isnull().values.any()
# Out:
# False

# %%
#Data kosong pada kolom
df_test_clean.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
df_test_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       441 non-null    float64
#  1   BusinessTravel            441 non-null    int8
#  2   DailyRate                 441 non-null    float64
#  3   Department                441 non-null    object
#  4   DistanceFromHome          441 non-null    float64
#  5   Education                 441 non-null    int64
#  6   EducationField            441 non-null    object
#  7   EmployeeCount             441 non-null    int64
#  8   EmployeeNumber            441 non-null    int64
#  9   EnvironmentSatisfaction   441 non-null    int64
#  10  Gender                    441 non-null    object
#  11  HourlyRate                441 non-null    int64
#  12  JobInvolvement            441 non-null    int64
#  13  JobLevel                  441 non-null    int64
# ...

# %% [markdown]
# ## 1.3 Visualisasi Korelasi Antar Variable Data Test

# %%
df_test_clean.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Plot korelasi dengan heatmap
plt.figure(figsize=(28,20)) 
plt.title(f'Correlation Matrix for Data Test ', fontsize=30)
sns.heatmap(df_test_clean[['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
       'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
       'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
       'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
       'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']].corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:title={'center':'Correlation Matrix for Data Training '}>

# %%
df_test_clean.corr().abs()
# Out:
#                                Age  BusinessTravel  DailyRate  \
# Age                       1.000000        0.010188   0.035688
# BusinessTravel            0.010188        1.000000   0.018778
# DailyRate                 0.035688        0.018778   1.000000
# DistanceFromHome          0.057921        0.019590   0.032834
# Education                 0.113046        0.020468   0.088379
# EmployeeCount                  NaN             NaN        NaN
# EmployeeNumber            0.009015        0.051948   0.060019
# EnvironmentSatisfaction   0.042531        0.053729   0.056635
# HourlyRate                0.015795        0.008680   0.000582
# JobInvolvement            0.001926        0.089562   0.058389
# JobLevel                  0.449794        0.045938   0.037774
# JobSatisfaction           0.041130        0.080686   0.068621
# MaritalStatus             0.134251        0.058180   0.036463
# MonthlyIncome             0.439321        0.051650   0.023830
# ...

# %%
df_test_clean2 = df_test_clean.drop(['BusinessTravel', 'DailyRate','DistanceFromHome','Department', 'Education','EducationField', 'EmployeeCount', 'EmployeeNumber',
                'EnvironmentSatisfaction', 'Gender', 'HourlyRate','JobInvolvement', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
                'MonthlyRate','NumCompaniesWorked','Over18', 'OverTime', 'RelationshipSatisfaction',
                'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance'], axis=1)
# mengambil data berdasar pedoman interpretasi koefisien korelasi
# Data Sedang = 0,40 - 0,599
# Data Kuat = 0,60 - 0,799
# Data Sangat Kuat = 0,80 - 1,0

# %%
df_test_clean2
# Out:
#       Age  JobLevel  MonthlyIncome  PercentSalaryHike  PerformanceRating  \
# 0    38.0         2           8463                 18                  3
# 1    53.0         2           4450                 11                  3
# 2    24.0         1           1555                 11                  3
# 3    45.0         3           9724                 17                  3
# 4    36.0         2           5914                 16                  3
# ..    ...       ...            ...                ...                ...
# 436  33.0         2           4373                 14                  3
# 437  27.0         2           6349                 13                  3
# 438  38.0         1           3464                 13                  3
# 439  39.0         2           5204                 11                  3
# 440  38.0         1           2074                 12                  3
#
#      TotalWorkingYears  YearsAtCompany  YearsInCurrentRole  \
# ...

# %%
plt.figure(figsize=(10,8))
plt.title(f'Correlation Matrix for Data Test', fontsize=25)
sns.heatmap(df_test_clean2.corr(), annot=True, cmap='gist_yarg_r')
#mengambil data berdasar pedoman interpretasi koefisien korelasi
# Data Sedang = 0,40 - 0,599
# Data Kuat = 0,60 - 0,799
# Data Sangat Kuat = 0,80 - 1,0
# Out:
# <AxesSubplot:title={'center':'Correlation Matrix for Data Test'}>
